# %%
# INTEGER TO FLOAT CONVERSION 
a=20
print(type (a)) # TYPE() ka use data type check krne ke liye
print(a) 
b = float (a)
print(b)
print(type (b))

# %%
# FLOAT TO INTEGER CONVERSION 
a = 10.5 
print(type (a))
print(a)
b = int (a)
print(b)
print(type (b))

# %%
# Boolean to integer and float 

# true conversion 
a= True # true ka data typr bool h --
print(type (a ))
print(a)

b = float (a)
print(b)
print(type (b))

b = int (a)
print(b)
print(type (b))

# FALSE conversion

a = False # false ka data type bool h
print( type ( a))
print(a)

b = float (a)
print(a)
print(type (b))

b = int (a)
print(b)
print(type (b))

# %%
# compex number 
x = 5 
y = 9 

z = complex (x,y)
print(type (z))
print(z)

print(z.real)
print(z.imag)

# %%
# direct method 
a = 3 + 9j 
b = 1 + 5j

print(type (a))
print(type (b))

print(a+b)
print(a-b)
print(a.real)
print(a.imag)

# %%
# None type
a = None 
print(type (a ))
print(a)

# String to float conversion

a = "20.5"
print(type(a))
print(a) 

b = float (a)
print(b)
print(type (b))

# string to integer conversion 

a = "20"
print(type(a))
print(a)

b = int (a)
print(type (b))
print(b)

# %%
# STRING DATA TYPES     # INDEXING IN STRING 
 
str1 = "welcome"
print(str1[3]) # forward indexing 
print(str1[-4]) # backward indexing
print(str1 [-1])
print(str1[-7])

# %%
# SLICING INDEXING FORWARD 

str1 = "welcome"

print(str1[0:6]) # stop value include nhi hoti h stop me 
print(str1[0:7])
print(str1[3:7])
print(str1[5:7])
print(str1[0:3])

str1 = "welcome"

print(str1[:7])
print(str1[0:])
print(str1[:])

print(str1[::])
print(str1[0:7:3])# FORMUla 0+3=3 3+3 = 6
print(str1[3:4])
print(str1[0:7])

print(str1[3:3])
print(str1[-7:-1])
print(str1[-7:])
print(str1[-7:7])
print(str1[-7:0])

# %%
str1 = "welcome"
print(str1[-7:-1]) # step value hum zero nhi de skte

# %%
# slicing backward
str1 = "welcome"
print(str1[-1:-8])
print(str1[-1:-8:-1])
print(str1[::-1])  
print(str1[::-2])
print(str1[3:0:-1])
print(str1[3:7:-1])

# %%
str1= "welcome"
print(str1 [1])
print(str1 [0:6])
print(str1 [0:3])
print(str1 [2:5])
print(str1 [:6])
print(str1 [3:])
print(str1 [:])
print(str1 [-1:-6])
print(str1 [-1:-7:-1])
print(str1 [1:6:2])
print(str1 [0:6:2])
print(str1 [::-1])
print(str1 [2:6:-1])
print(str1 [-6:6])
print(str1 [0:6:0])

# %%
# string concatenate operator 
str1 = "hellow"
str2 = "world"
str3 = str1 + str2
print(str3)
print("ducat"+"     india  ")

# %%
# string replicate operators
str1 = "hellow"
str2 = "world"
print(str1 * 6)
print(3*str2)

# %%
# replicate operator ko hum pahle bhi de skte h 
print("*" *45 )
print("        employee management system")
print("*" *45)

# %%
print("+-*/-" *45 )
print("                           employee management system")
print("*-*%/" *45)

# %%
# .capitalize()  :- yh string ke first letter ko capital krta h 
str1 = "welcome to ducat"
print(str1.capitalize())

# %%
# .title() :- yh har word ka first letter capital krta h 
str1= "welcome to ducat"
print(str1.title())

# %%
# .upper() :- sare letter ko capital krta h 
str1 = "welcome to ducat"
print(str1.upper())

# %%
# .count(string,begin,en) :- begin se end tak diye gaye character ya string ko count krta h 
str1 = "welcome to python programmeng"
print(str1.count("o"))
print(str1.count("me"))
print(str1.count("o",6))
print(str1.count("o",6,10))

# %%
# .endswith(string,begin,end) :- yh only end letter ko print krega 
str1 = "welcome to ducat"
print(str1.endswith("ducat"))
print(str1.endswith("to"))
print(str1.endswith("wel"))
print(str1.endswith("0,20"))

# %%
# .starts(string,begin,end) :- yh only starts letter ko print krega 
str1 = "welcome to ducat"
print(str1.startswith("welcome"))
print(str1.startswith("to"))
print(str1.startswith("come"))
print(str1.startswith("welcome",0,8))

# %%
# .find(string, begin , end) :- yh string find krta h [ yh string na milne pr error nhi dega (-1) ayega ]
str1 = "welcome to python programming"
print(str1.find("come"))
print(str1.find("to"))
print(str1.find("wel"))
print(str1.find("python"))
print(str1.find("come",20))
print(str1.find("wel",5))

# %%
# .index(string, begin , end) :- yh string find krta h [ yh string na milne pr error nhi dega (error) ayega ]
str1 = "welcome to python programming"
print(str1.index("come"))
print(str1.index("to"))
print(str1.index("wel"))
print(str1.index("python"))
print(str1.index("come",20))
print(str1.index("wel",5))

# %%
# .isalnum()  (isme ya to all num ho ya to alphabet ya dono ka combination and isme space hoga to false ayega)
str1 = "welcome to python programming"
str2 = "python programming3.14.6"
str3 = "python programming $"
str4 = "python2544458717"
str5 = "pythonprogramming"
str6 = "python programming"
print(str1.isalnum())
print(str2.isalnum())
print(str3.isalnum())
print(str4.isalnum())
print(str5.isalnum())
print(str6.isalnum())

# %%
# .isalpha() (isme only alphabet ho to true ayega ( space hoga to false ayega ) )
str1 = "welcome to python programming"
str2 = "python programming3.14.6"
str3 = "python programming $"
str4 = "python2544458717"
str5 = "pythonprogramming"
str6 = "pythonprogramming"
print(str1.isalpha())
print(str2.isalpha())
print(str3.isalpha())
print(str4.isalpha())
print(str5.isalpha())
print(str6.isalpha())

# %%
# .isdigit() :- isme only number hona chaiye
str1 = "welcome to python programming"
str2 = "python programming3.14.6"
str3 = "python programming $"
str4 = "2544458717"
str5 = "pythonprogramming"
str6 = "pythonprogramming"
print(str1.isdigit())
print(str2.isdigit())
print(str3.isdigit())
print(str4.isdigit())
print(str5.isdigit())
print(str6.isdigit())

# %%
# .islower() :- isme sab hota h num special num space (letter small me hona chiye)
str1 = "Welcome to python programming"
str2 = "python$+-545 programming3.14.6"
str3 = "python programming $"
str4 = "2544458717"
str5 = "pythonprogramming"
str6 = "pythonprOgramming"
print(str1.islower())
print(str2.islower())
print(str3.islower())
print(str4.islower())
print(str5.islower())
print(str6.islower())

# %%
# .islower() :- isme sab hota h num special num space (letter capital me hona chiye)
str1 = "WELCOME TO PYTHON PROGRAMMING"
str2 = "python$+-545 programming3.14.6"
str3 = "python programming $"
str4 = "2544458717"
str5 = "pythonprogramming"
str6 = "pythonprOgramming"
print(str1.isupper())
print(str2.isupper())
print(str3.isupper())
print(str4.isupper())
print(str5.isupper())
print(str6.isupper())

# %%
# .isspace() :- isme only space hona chaiye
str1 = "          "
str2 = "python$+-545 programming3.14.6"
str3 = "python programming $"
str4 = "   "
str5 = "pythonprogramming"
str6 = "pythonprOgramming"
print(str1.isspace())
print(str2.isspace())
print(str3.isspace())
print(str4.isspace())
print(str5.isspace())
print(str6.isspace())

# %%
# .swapcase()  :- yh capital letter ko small me or small ko capital me krta h 
str1 = "WELCOME TO PYTHON PROGRAMMING"
str2 = "python$+-545 programming3.14.6"
str3 = "python programming $"
str4 = "2544458717"
str5 = "pythonprogramming"
str6 = "pythonprOgramming"
print(str1.swapcase())
print(str2.swapcase())
print(str3.swapcase())
print(str4.swapcase())
print(str5.swapcase())
print(str6.swapcase())

# %%
# .strip() :- yh left side ka space hata ta h 
str1 = "     WELCOME TO PYTHON PROGRAMMING   |"
str2 = "python$+-545 programming3.14.6"
str3 = "python programming $"
str4 = "2544458717"
str5 = "pythonprogramming"
str6 = "pythonprOgramming"
print(str1.lstrip())
print(str2.lstrip())
print(str3.lstrip())
print(str4.lstrip())
print(str5.lstrip())
print(str6.lstrip())

# %%
# .rstri() :- yh right side ka space hata h 
str1 = "     WELCOME TO PYTHON PROGRAMMING      "
str2 = "python$+-545 programming3.14.6"
str3 = "python programming $"
str4 = "2544458717"
str5 = "pythonprogramming"
str6 = "pythonprOgramming"
print(str1.rstrip())
print(str2.rstrip())
print(str3.rstrip())
print(str4.rstrip())
print(str5.rstrip())
print(str6.rstrip())

# %%
# .strip() :- yh dono side ka space remove krta h 
str1 = "    WELCOME TO PYTHON PROGRAMMING   "
str2 = "python$+-545 programming3.14.6"
str3 = "python programming $"
str4 = "2544458717"
str5 = "pythonprogramming"
str6 = "pythonprOgramming"
print(str1.strip())
print(str2.strip())
print(str3.strip())
print(str4.strip())
print(str5.strip())
print(str6.strip())

# %%
# .replace() :- data ko clean krta h
str1 = '''python is a high level language .
python is a lossely type language.
python is a object oriented language.
python is a interpreter based language,'''
str2 = (" python $is a $$interpreter based $ language")

print(str2.replace("$",""))
print(str1.replace("python","R- language"))
print(str1.replace("python","R-language",2))
print(str1.replace(" ",""))# space remove
print(str1.replace(""," "))

# %%
# len() :- string ki length count krta h 
str1 = '''python is a high level language .
python is a lossely type language.
python is a object oriented language.
python is a interpreter based language,'''
print(len(str1)) # space v count krra h 
print(len(str1.replace(" ","")))

# %%
# .join() :- string ko combine krta h 
str1 = "welcome"
str2 = "to"
str3 = "ducat"
str4 = "sector-16"
str5 = "noida"
print("_".join([str1,str2,str3,str4,str5]))
print("".join([str1,str2,str3,str4,str5]))

# %%
# .split() :- string ko multiple part me break  karta h
str1 = "welcome to ducat sector-16 noida"
print(str1.split())
result = str1.split()
print(result [2])
result = str1.split('o')
print(result)

# %%
# ACCESSING LIST 
data1 = [1,2 ,3,4]
data2 = ['x','y','z']
data3 = [2.5, 8.9, 7.6]
data4 = ['aman','bipin','deepak',]
data5 = ['pankaj', 10, 4.5, 'a']

print(data1[0])
print(data1[0:2])
print(data2[-3:-1])
print(data1[0:])
print(data2[:2])
print(data3[0:])
print(data3[0:2])
print(data4[0:2])
print(data5[0:2])
print(data5[-3:-1])
print(data5[::-1])
print(data5[1:4:-1])
print(data5[-1:-5:-2])
print(data5[1:2])
print(data5[2:0:-1])

# %%
# LIST CONCATENATE operator (+) :- more than data ko combine krta h 
list1 = (10,20,30,40)
list2 = ('a','b','c','d','e')
list3 = list1+list2
print(list3)

# %%
# REPLICATE OPERATOR (*) :- yh repeat krta h 
list1 = (10,20,30,40)
list2 = ('a','b','c','d','e')
print(list1*3)
print(2*list2)

# %%
# UPDATION OF LIST ELEMENTS
data = [10,20.5,30,40.5,50]
print(data)
data[1] = 'multiple of 5'
data[0] = "hello"
print(data)

# %%
# APPENING OF LIST ELEMENTS METHOD 

# .append() :- yh elements add krta h ek br me ek or last me add krta h 

data = [10, 20, 20.5,30, 40.5]
data.append(50)
print(data)

# %%
# DEL KEYWORD 
data = [10, 20, 20.5,30, 40.5]
print(data)
del(data [0])
del(data[:3])
print(data)
del(data)

# %%
# .clear() yh empty ke liye use hota h 
data = [10, 20, 20.5,30, 40.5]
data.clear()
print(data)
data.append('aman')
data.append('deepak')
data.append('pankaj')
print(data)

# %%
# LIST HANDLING FUNCTIONS & METHOD
# MIN(LIST) :- min value find krta h
data = [4,8,2,1,12,18,3,4.5,2.5,20]
print(min(data))

# %%
# MAX(LIST) :- max value find krta h 
data = [4,8,2,1,12,18,3,4.5,2.5,20]
print(max(data))

# %%
# len() :- yh length find krta h
data = [4,8,2,1,12,18,3,4.5,2.5,20]
print(len(data))

# %%
# min(list) # ASCII VALUE PR WORK KATA H 
# [A-Z(65-90)]
# [a-z(97-122)]
data = ['pankaj','aman','Bipin','saroj','raj']
print(min(data))

# %%
# .index(object) :- find index
data = [10,20,30,40,15,10,50,20,10,50]
print(data.index(10))

# %%
# .count(object):- count value
data = [10,20,30,40,15,10,50,20,10,50]
print(data.count(10))

# %%
# .pop() :- yh 1 elements ko remove krega
data = [10,20,30,40,15,10,50,20,10,50]
print(data.pop(3))
print(data.pop()) # isme last me remone krega

# %%
# .insert() :- isme kahi n elements add krlo
data = [10,20,30,40,15,10,50,20,10,50]
data.insert(0,20.5)
print(data)
data.insert(3,'pankaj')
print(data)

# %%
# .extend(squence) :- yh last me value add krta or one more than value add
data = [10,20,30,40,15,10,50,20,10,50]
data.extend([60,70.5,80,90])
print(data)

# %%
data = [10,20,30,40,15,10,50,20,10,50]
data.remove(30)
print(data)

# %%
# .reverse() 
data = [7,9,3,2,10,2.5,7.8,10,3]
data.reverse()
print(data)
data1 = [7,9,3,2,10,2.5,7.8,10,3]
print(data1[::-1])

# %%
# .SORT() / .SORT(REVERSE = TRUE)
# isme hum all no. ya all string de skte
data = [7,9,3,2,10,2.5,7.8,10,3]
data.sort() # aasending order
print(data)
data.sort(reverse=True) # dessending order
print(data1)
data = ['pankaj','aman','raj','saroj']
data.sort()
print(data)

# %%
# NESTED LIST (LIST OF LIST) :- ISME HUM MULTIPLE STRING USE KR SKTE H 

record = ['welcome',['aman','raj','pankaj','kamlesh','saroj'],[67,89,34,56,]]
print(record)
print(record[0])
print(record[1])
print(record[2])
print(record[1][1])
print(record[1][4][4])
print(record[1][2])
print(record[1][3][6])
print(record[1][1][::-1])
print(record[0][3:4])
print(record[0][::-2])
print(record[2][2])
print(record[1][2][:3]) 
print(record[1][4][2:])
print(record[1][3][3:0:-1])
print(record[1][4][-4:-1])
print(record[1][4][-4:-1])
#print(record[1][::0])
print(record[1][3][1:6:-1])
print(record[1][3][1:6:-1])
print(record[2][::-1])

# %%
# NESTED LIST 
record = ['welcome',[[2,3,4,5],['aman','raj','pankaj','kamlesh','saroj'],[67,89,34,56,]]]
print(record[1][1][1])
print(record[1][1][1][::-1])
print(record[1][1][2][3])

# %%
# TUPLE DATA TYPE IN PYTHON

a = [10,20,30,40,50]
type(a)

b = (10,20,30,40,50)
type(b)
c = (10,20,30,40,50)
type(c), type(b), type(a)

a = (10)
type(a)
a = 10,
type(a)

# %%
# tuple accessing
data1 = (1,2,3,4)
data2 = ('x','y','z')
data3 = (10,20,'aman',34.5)
data4 = ("a",10,16.5)

print(data1[0])
print(data4[0:2])
print(data2[-3:-1])
print(data1[0:])
print(data2[:2])
print(data3[-4:-1])
print(data4[0:])

# %%
# NESTED TUPLE (TUPLE OF TUPLE)
data = ((10,20,30,40),
       ('aman','deepak','pankaj','raj'),
        (10.5,20.5,30.5,40.5))

print(data[0][0])
print(data[1][1])
print(data[1][3][::-1])
print(data[2][2])
print(data[1][2][::-1])
print(data[1][2])

# %%
# tuple concatenate operator (+) :- combine
tup1 = (10,20,30,40)
tup2 = ('a','b','c','d')
tup3 = tup1 + tup2
print(tup3)

# %%
# replicate operator (*) :- repeat
tup1 = (10,20,30,40)
tup2 = ('a','b','c','d')
print(tup1*4)
print(tup2*3)

# %%
# udation of tuple :- tuple me update nhi kr skte h 
data = (10,20,30,40)
print(data)
print(type(data))
data[2] ='multiple of 5'
print(data)

# %%
# deletion of tuple 
data = (10, 20, 30 , 40 ,50)
del data
print(data)

# %%
tup1 = (10,20,30,40)
print(min(tup1))

# %%
tup1 = (10,20,30,40)
print(max(tup1))

# %%
tup1 = (10,20,30,40)
print(len(tup1))

# %%
tup1 = (10,20,30,40)
print(tup1.index(30))

# %%
tup1 = (10,20,30,40,20)
print(tup1.count(20))
